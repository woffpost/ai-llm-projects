# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from dotenv import load_dotenv
import os

load_dotenv
api_key = os.getenv("ANTHROPIC_API_KEY")
client = ChatAnthropic(
    model="claude-opus-4-5",
    api_key=api_key,
    max_tokens=1024
)

system = SystemMessage(content="Ты эксперт по советским масштабным моделям 1:43.")

history = [system]

while True:
    user_input = input("Ты: ")
    if user_input.lower() == "выход":
        break
    
    history.append(HumanMessage(content=user_input))
    response = client.invoke(history)
    history.append(AIMessage(content=response.content))
    
    print(f"Бот: {response.content}\n")
# Out:
# Бот: # Москвич-А8 «Патрульная»
#
# Это модель производства **Тантал** (Саратов), выпускавшаяся примерно с **1982-1983 года**.
#
# ## Основные характеристики
#
# **Прототип:** Москвич-412 в милицейском исполнении
#
# **Особенности модели:**
# - Характерная жёлто-синяя окраска советской милиции
# - Проблесковый маячок на крыше
# - Надписи «Милиция» или «ГАИ» (в зависимости от варианта)
#
# ## Варианты исполнения
#
# Встречались версии:
# - С синими и жёлтыми полосами (классическая схема ГАИ)
# - Разные варианты надписей на бортах
# - Отличия в оттенках окраски (жёлтый мог варьироваться)
#
# ## Коллекционная ценность
#
# Модель достаточно распространённая, но в хорошем состоянии с яркой, нецарапаной окраской ценится выше. Особенно интересны ранние выпуски.
#
# ---
#
# Вас интересует что-то конкретное — варианты, цены, отличия от других милицейских моделей Тантала?
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[3], line 20
#      17     break
#      19 history.append(HumanMessage(content=user_input))
# ---> 20 response = client.invoke(history)
#      21 history.append(AIMessage(content=response.content))
#      23 print(f"Бот: {response.content}\n")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)   1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1520, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1518     data = self._create(payload)
#    1519 except anthropic.BadRequestError as e:
# -> 1520     _handle_anthropic_bad_request(e)
#    1521 return self._format_output(data, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1518, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1516 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1517 try:
# -> 1518     data = self._create(payload)
#    1519 except anthropic.BadRequestError as e:
#    1520     _handle_anthropic_bad_request(e)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1190, in ChatAnthropic._create(self, payload)
#    1188 if "betas" in payload:
#    1189     return self._client.beta.messages.create(**payload)
# -> 1190 return self._client.messages.create(**payload)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1134             err.response.read()
#    1136         log.debug("Re-raising status error")
# -> 1137         raise self._make_status_error_from_response(err.response) from None
#    1139     break
#    1141 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.2: user messages must have non-empty content'}, 'request_id': 'req_011CZceHuyqjD4L8awdoAUTd'}
